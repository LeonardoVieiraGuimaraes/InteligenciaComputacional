# %% [markdown]
# ### Descrição Detalhada dos Datasets Utilizados
#
# #### 1. Energy Efficiency Dataset
# - **Contexto:** Este conjunto de dados foi criado para avaliar o desempenho energético de edifícios residenciais. Cada linha representa um edifício simulado com diferentes características construtivas e ambientais.
# - **Atributos de entrada:**
#   - X1: Relative Compactness
#   - X2: Surface Area
#   - X3: Wall Area
#   - X4: Roof Area
#   - X5: Overall Height
#   - X6: Orientation
#   - X7: Glazing Area
#   - X8: Glazing Area Distribution
# - **Variáveis alvo:**
#   - Y1: Heating Load (carga térmica de aquecimento)
#   - Y2: Cooling Load (carga térmica de resfriamento)
# - **Aplicação:** Utilizado para tarefas de regressão, visando prever o consumo energético de aquecimento e resfriamento de edifícios a partir das características físicas e ambientais.
# - **Observações:** Não possui valores ausentes. Todos os atributos são numéricos.
#
# #### 2. Wine Quality Dataset (Red)
# - **Contexto:** Este conjunto de dados contém informações físico-químicas de vinhos tintos portugueses, coletados para estudar a relação entre essas características e a qualidade sensorial do vinho.
# - **Atributos de entrada:**
#   - fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol
# - **Variável alvo:**
#   - quality: Nota de qualidade do vinho (escala de 0 a 10, atribuída por especialistas)
# - **Aplicação:** Utilizado para tarefas de classificação multiclasse, buscando prever a nota de qualidade do vinho a partir das características físico-químicas.
# - **Observações:** Não possui valores ausentes. Todos os atributos são numéricos. A distribuição das classes é desbalanceada (maioria dos vinhos tem nota entre 5 e 7).
#
# #### 3. Iris Dataset
# - **Contexto:** Um dos conjuntos de dados mais clássicos da estatística e machine learning, utilizado para classificação de espécies de flores do gênero Iris. Cada linha representa uma flor coletada.
# - **Atributos de entrada:**
#   - sepal_length: comprimento da sépala
#   - sepal_width: largura da sépala
#   - petal_length: comprimento da pétala
#   - petal_width: largura da pétala
# - **Variável alvo:**
#   - class: Espécie da flor (Iris setosa, Iris versicolor, Iris virginica)
# - **Aplicação:** Utilizado para tarefas de classificação multiclasse, buscando identificar a espécie da flor a partir das medidas morfológicas.
# - **Observações:** Não possui valores ausentes. As classes são balanceadas (50 amostras de cada espécie).

# %%
# Carregamento e Download dos Dados para pasta 'dataset'

import os
import urllib.request
import pandas as pd

# Cria a pasta 'dataset' se não existir
os.makedirs('dataset', exist_ok=True)

# URLs dos datasets
energy_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'
wine_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
iris_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

# Caminhos locais
energy_path = 'dataset/ENB2012_data.xlsx'
wine_path = 'dataset/winequality-red.csv'
iris_path = 'dataset/iris.data'

# Download dos arquivos se não existirem
if not os.path.exists(energy_path):
    urllib.request.urlretrieve(energy_url, energy_path)
if not os.path.exists(wine_path):
    urllib.request.urlretrieve(wine_url, wine_path)
if not os.path.exists(iris_path):
    urllib.request.urlretrieve(iris_url, iris_path)

# Carregamento dos dados
df_energy = pd.read_excel(energy_path)
df_wine = pd.read_csv(wine_path, sep=';')
iris_columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
df_iris = pd.read_csv(iris_path, names=iris_columns)

# Visualização das primeiras linhas
print("Energy Efficiency Dataset:")
print(df_energy.head())
print("\nWine Quality Dataset (Red):")
print(df_wine.head())
print("\nIris Dataset:")
print(df_iris.head())
# Out:
# Energy Efficiency Dataset:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
#
# Wine Quality Dataset (Red):
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# Informações detalhadas dos datasets

print("=== Energy Efficiency Dataset ===")
print("Shape:", df_energy.shape)
print("Colunas:", df_energy.columns.tolist())
print("Tipos de dados:\n", df_energy.dtypes)
print("Valores ausentes por coluna:\n", df_energy.isnull().sum())
print("Estatísticas descritivas:\n", df_energy.describe())

print("\n=== Wine Quality Dataset (Red) ===")
print("Shape:", df_wine.shape)
print("Colunas:", df_wine.columns.tolist())
print("Tipos de dados:\n", df_wine.dtypes)
print("Valores ausentes por coluna:\n", df_wine.isnull().sum())
print("Estatísticas descritivas:\n", df_wine.describe())

print("\n=== Iris Dataset ===")
print("Shape:", df_iris.shape)
print("Colunas:", df_iris.columns.tolist())
print("Tipos de dados:\n", df_iris.dtypes)
print("Valores ausentes por coluna:\n", df_iris.isnull().sum())
print("Estatísticas descritivas:\n", df_iris.describe())
print("Classes únicas:", df_iris['class'].unique())
# Out:
# === Energy Efficiency Dataset ===
# Shape: (768, 10)
# Colunas: ['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'Y1', 'Y2']
# Tipos de dados:
#  X1    float64
# X2    float64
# X3    float64
# X4    float64
# X5    float64
# X6      int64
# X7    float64
# X8      int64
# Y1    float64
# Y2    float64
# dtype: object
# Valores ausentes por coluna:
#  X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# Y2    0
# dtype: int64
# Estatísticas descritivas:
#                 X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# ...
