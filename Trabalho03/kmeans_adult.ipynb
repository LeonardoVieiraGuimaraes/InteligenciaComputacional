# %% [markdown]
# # Classificação do Dataset Adult com KMeans Supervisionado
#
# Este notebook implementa a classificação do dataset Adult utilizando KMeans supervisionado, com download automático dos dados, avaliação em 30 execuções e salvamento dos resultados (matriz de confusão e gráficos) na pasta `img`.

# %%
# Importar bibliotecas necessárias
import os
import numpy as np
import pandas as pd
from urllib.request import urlretrieve
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score, confusion_matrix
from scipy.stats import mode
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Carregar e visualizar o dataset Adult a partir da pasta data
import pandas as pd

columns = [
    'age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status',
    'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss',
    'hours-per-week', 'native-country', 'income'
]
data_path = 'data/adult.data'
test_path = 'data/adult.test'
df_train = pd.read_csv(data_path, names=columns, sep=',', skipinitialspace=True)
df_test = pd.read_csv(test_path, names=columns, sep=',', skipinitialspace=True, skiprows=1)
df = pd.concat([df_train, df_test], ignore_index=True)
df = df.replace('?', pd.NA).dropna()
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# Pré-processamento dos dados
from sklearn.preprocessing import LabelEncoder

def preprocess_adult(df):
    X = df.drop('income', axis=1)
    y = df['income'].apply(lambda x: 1 if '>50K' in x else 0)
    X = pd.get_dummies(X)
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled, y.values

X, y = preprocess_adult(df)
print(f"Shape dos dados após preprocessamento: {X.shape}")
# Out:
# Shape dos dados após preprocessamento: (45222, 104)

# %%
# Implementação do classificador KMeans supervisionado

def elbow_method(X, max_k=15, random_state=None):
    distortions = []
    K = range(2, max_k+1)
    for k in K:
        kmeans = KMeans(n_clusters=k, random_state=random_state, n_init=10)
        kmeans.fit(X)
        distortions.append(kmeans.inertia_)
    deltas = np.diff(distortions)
    elbow = np.argmin(deltas) + 2
    return K[elbow]

class SupervisedKMeansClassifier:
    def __init__(self, max_k=15, random_state=None):
        self.max_k = max_k
        self.random_state = random_state
        self.kmeans = None
        self.n_clusters = None
        self.cluster_labels = None
    def fit(self, X, y):
        self.n_clusters = elbow_method(X, self.max_k, self.random_state)
        self.kmeans = KMeans(n_clusters=self.n_clusters, random_state=self.random_state, n_init=10)
        clusters = self.kmeans.fit_predict(X)
        self.cluster_labels = np.zeros(self.n_clusters, dtype=int)
        for i in range(self.n_clusters):
            mask = (clusters == i)
            if np.any(mask):
                self.cluster_labels[i] = mode(y[mask], keepdims=True)[0][0]
            else:
                self.cluster_labels[i] = 0
    def predict(self, X):
        clusters = self.kmeans.predict(X)
        return self.cluster_labels[clusters]

# %%
# Treinamento, avaliação e salvamento dos resultados
accs = []
cms = []
for seed in range(1, 31):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=seed, stratify=y)
    clf = SupervisedKMeansClassifier(random_state=seed)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)
    accs.append(acc)
    cms.append(cm)
    print(f"Execução {seed:02d}: Acurácia = {acc:.4f}")
accs = np.array(accs)
cms = np.array(cms)
# Out:
# Execução 01: Acurácia = 0.7522
# Execução 02: Acurácia = 0.7731
# Execução 02: Acurácia = 0.7731
# Execução 03: Acurácia = 0.7522
# Execução 03: Acurácia = 0.7522
# Execução 04: Acurácia = 0.7522
# Execução 04: Acurácia = 0.7522
# Execução 05: Acurácia = 0.7807
# Execução 05: Acurácia = 0.7807
# Execução 06: Acurácia = 0.7696
# Execução 06: Acurácia = 0.7696
# Execução 07: Acurácia = 0.7522
# Execução 07: Acurácia = 0.7522
# Execução 08: Acurácia = 0.7734
# Execução 08: Acurácia = 0.7734
# Execução 09: Acurácia = 0.7522
# Execução 09: Acurácia = 0.7522
# Execução 10: Acurácia = 0.8080
# Execução 10: Acurácia = 0.8080
# Execução 11: Acurácia = 0.7522
# Execução 11: Acurácia = 0.7522
# Execução 12: Acurácia = 0.7734
# Execução 12: Acurácia = 0.7734
# Execução 13: Acurácia = 0.7522
# Execução 13: Acurácia = 0.7522
# Execução 14: Acurácia = 0.7522
# Execução 15: Acurácia = 0.7522
# Execução 16: Acurácia = 0.7522
# Execução 17: Acurácia = 0.7522
# Execução 18: Acurácia = 0.8133
# Execução 19: Acurácia = 0.7731
# Execução 20: Acurácia = 0.7801
# Execução 21: Acurácia = 0.7522
# Execução 22: Acurácia = 0.7522
# Execução 23: Acurácia = 0.7522
# Execução 24: Acurácia = 0.7609
# Execução 25: Acurácia = 0.7794
# Execução 26: Acurácia = 0.7771
# Execução 27: Acurácia = 0.7522
# Execução 28: Acurácia = 0.7994
# Execução 29: Acurácia = 0.7522
# Execução 30: Acurácia = 0.7753
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 18
#      15 cms = np.array(cms)
#      17 # Salvar matrizes e gráficos
# ---> 18 np.save('Trabalho03/img/kmeans_adult_matrizes_confusao.npy', cms)
#      19 np.save('Trabalho03/img/kmeans_adult_acuracias.npy', accs)
#      21 # Gráfico de acurácia
#
# File d:\GitHub\DoutoradoCefet\InteligenciaComputacional\.venv\Lib\site-packages\numpy\lib\_npyio_impl.py:577, in save(file, arr, allow_pickle, fix_imports)
#     575     if not file.endswith('.npy'):
#     576         file = file + '.npy'
# --> 577     file_ctx = open(file, "wb")
#     579 with file_ctx as fid:
#     580     arr = np.asanyarray(arr)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Trabalho03/img/kmeans_adult_matrizes_confusao.npy'

# %%
# Salvar matrizes e gráficos
np.save('img/kmeans_adult_matrizes_confusao.npy', cms)
np.save('img/kmeans_adult_acuracias.npy', accs)

# Gráfico de acurácia
plt.figure(figsize=(8,4))
plt.plot(range(1,31), accs, marker='o')
plt.title('Acurácia em cada execução (KMeans + Adult)')
plt.xlabel('Execução')
plt.ylabel('Acurácia')
plt.grid()
plt.savefig('Trabalho03/img/kmeans_adult_acuracia.png')
plt.show()

# Matriz de confusão média
cm_mean = np.round(cms.mean(axis=0)).astype(int)
sns.heatmap(cm_mean, annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de Confusão Média (KMeans + Adult)')
plt.xlabel('Previsto')
plt.ylabel('Real')
plt.savefig('Trabalho03/img/kmeans_adult_cm_media.png')
plt.show()

print(f"Acurácia média: {accs.mean():.4f}")
print(f"Desvio padrão da acurácia: {accs.std():.4f}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Salvar matrizes e gráficos
# ----> 2 np.save('Trabalho03/img/kmeans_adult_matrizes_confusao.npy', cms)
#       3 np.save('Trabalho03/img/kmeans_adult_acuracias.npy', accs)
#       5 # Gráfico de acurácia
#
# File d:\GitHub\DoutoradoCefet\InteligenciaComputacional\.venv\Lib\site-packages\numpy\lib\_npyio_impl.py:577, in save(file, arr, allow_pickle, fix_imports)
#     575     if not file.endswith('.npy'):
#     576         file = file + '.npy'
# --> 577     file_ctx = open(file, "wb")
#     579 with file_ctx as fid:
#     580     arr = np.asanyarray(arr)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Trabalho03/img/kmeans_adult_matrizes_confusao.npy'
